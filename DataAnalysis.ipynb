# %%
import pandas as pd
url = r"C:\Users\usuario\Documents\Analisis de Datos\train.csv"

df = pd.read_csv(url)

df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
cabecera = ["PassengerId", "Survived", "Pclass", "Name", "Sex", "Age", "SibSp", "Parch", "Ticket", "Fare", "Cabin", "Embarked"]
df.columns = cabecera
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(include="all")
# Out:
#         PassengerId    Survived      Pclass                 Name   Sex  \
# count    891.000000  891.000000  891.000000                  891   891
# unique          NaN         NaN         NaN                  891     2
# top             NaN         NaN         NaN  Moor, Master. Meier  male
# freq            NaN         NaN         NaN                    1   577
# mean     446.000000    0.383838    2.308642                  NaN   NaN
# std      257.353842    0.486592    0.836071                  NaN   NaN
# min        1.000000    0.000000    1.000000                  NaN   NaN
# 25%      223.500000    0.000000    2.000000                  NaN   NaN
# 50%      446.000000    0.000000    3.000000                  NaN   NaN
# 75%      668.500000    1.000000    3.000000                  NaN   NaN
# max      891.000000    1.000000    3.000000                  NaN   NaN
#
#                Age       SibSp       Parch    Ticket        Fare    Cabin  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df["Age"].mean()
# Out:
# 29.69911764705882

# %%
pd.get_dummies(df, columns = ["Sex"], drop_first = True)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
import matplotlib.pyplot as plt
a = [3, 4, 5, 6]
b = [5, 6, 3, 4]

plt.bar(a,b,  label='a', width = 0.5, color = 'orange')
plt.bar(b,a, label='b', width = 0.5, color = 'blue')

plt.xlabel('Eje x')
plt.ylabel('Eje y')
plt.legend()
plt.show()

# %%
plt.plot(a, b)
plt.show()

# %%
pip install spotipy --upgrade
# Out:
# ...
#   Found existing installation: spotipy 2.7.1
#     Uninstalling spotipy-2.7.1:
#       Successfully uninstalled spotipy-2.7.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import json
import spotipy
import webbrowser
import spotipy.util as util
from json.decoder import JSONDecodeError

scope = 'user-library-read'
client_id='c7946ec1c2fd46508feee5dfbae0f7e2'
client_secret='63a58449e703486881c2d86e4dd11f9f'
redirect_uri='https://www.google.com/'

#borrar cache del usuario y dar permiso

if len(sys.argv) > 1:
    username = sys.argv[1]
else:
    print("Usage: %s username" % (sys.argv[0],))
    sys.exit()

token = util.prompt_for_user_token(username, scope, client_id, client_secret, redirect_uri)

if token:
    sp = spotipy.Spotify(auth=token)
    results = sp.current_user_saved_tracks()
    for item in results['items']:
        track = item['track']
        print(track['name'] + ' - ' + track['artists'][0]['name'])
else:
    print("Can't get token for", username)
        
#crear un objeto tipo spotify
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-add027af574d> in <module>
#      13 #borrar cache del usuario y dar permiso
#      14
# ---> 15 if len(sys.argv) > 1:
#      16     username = sys.argv[1]
#      17 else:
#
# NameError: name 'sys' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-548b168d4d9d> in <module>
# ----> 1 tracks_df
#       2
#       3
#       4
#
# NameError: name 'tracks_df' is not defined

# %%
#este codigo sí sirve
#------------------------------------------------------------------------------------
import spotipy
import sys
import requests
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.oauth2 as oauth2
import spotipy.util as util
CLIENT_ID = "c7946ec1c2fd46508feee5dfbae0f7e2"
CLIENT_SECRET = "63a58449e703486881c2d86e4dd11f9f"
REDIRECT_URI = "https://www.google.com/"

scope = 'user-library-read'
username = 'akemi.mtz99'
#track = "11dFghVXANMlKmJXsNCbNl"

credentials = oauth2.SpotifyClientCredentials(
        client_id=CLIENT_ID,
        client_secret=CLIENT_SECRET)

token = util.prompt_for_user_token(username, scope, client_id=CLIENT_ID, client_secret=CLIENT_SECRET, redirect_uri=REDIRECT_URI)

spotify = spotipy.Spotify(auth=token)

if token:
    sp = spotipy.Spotify(auth=token)
    results = sp.current_user_saved_tracks()
    for item in results['items']:
        track = item['track']
        print(track['name'] + ' - ' + track['artists'][0]['name'])
else:
    print("Can't get token for", username)
print(results)
# Out:
#             User authentication requires interaction with your
#             web browser. Once you enter your credentials and
#             give authorization, you will be redirected to
#             a url.  Paste that url you were directed to to
#             complete the authorization.
#
#
# Opened https://accounts.spotify.com/authorize?client_id=c7946ec1c2fd46508feee5dfbae0f7e2&response_type=code&redirect_uri=https%3A%2F%2Fwww.google.com%2F&scope=user-library-read in your browser

# %%
import requests
import json
from bs4 import BeautifulSoup
import re
import os

songs = []
lyrics = 'Desde Barcelona hasta Santa Marta'
#song_title = 'Aloha'
#artist_name = 'Carlos Sadness'
base_url = 'https://api.genius.com'
headers = {'Authorization': 'Bearer ' + 'iT3UxsD45-uuPA7xk2HNdcBStbhLoahWhVCKGqiR1IJ3OuO0ePtPlDTe7-70x_Xr'}
search_url = base_url + '/search'
data = {'q': lyrics}
print (data)


response = requests.get(search_url, data=data, headers=headers)


parsed = json.loads(response.text)

song_info = []
for hit in parsed['response']['hits']:
    if artist_name.lower() in hit['result']['primary_artist']['name'].lower():
        song_info.append(hit)

for song in song_info:
            if (len(songs) < 2):
                url = song['result']['url']
                songs.append(url)
                
print(songs)

def scrape_song_lyrics(url):
    page = requests.get(url)
    html = BeautifulSoup(page.text, 'html.parser')
    lyrics = html.find('div', class_='lyrics').get_text()
    #remove identifiers like chorus, verse, etc
    lyrics = re.sub(r'[\(\[].*?[\)\]]', '', lyrics)
    #remove empty lines
    lyrics = os.linesep.join([s for s in lyrics.splitlines() if s])         
    return lyrics

print(scrape_song_lyrics('https://genius.com/Carlos-sadness-aloha-lyrics'))
# Out:
# {'q': 'Desde Barcelona hasta Santa Marta'}
# ['https://genius.com/Carlos-sadness-aloha-lyrics']
# "]
# This is a message
# Para todos
# Los que alguna vez
# Se sintieron solos o solas
# Aloha
# ¿Hay alguien ahí?
# Sé que no estoy sola
# ¿Me puedes oír?
# Desde el otro lado de la galaxia
# Yo te traigo un rayito de esperanza
# Aunque creas que ahorita no hace falta
# Por si acaso, yo te quiero decir...
# Que no estás sola, o-ooh
# Por eso digo aloha, a-a-aah
# I don't feel alone now, o-o-ooh
# Aloha, a-a-aah
# Aloha
# ¿Tú quieres venir?
# Y cuando se muevan las olas
# Ya tú estés aquí
# Si a tus ojos no llega mi mirada
# Yo te soplo unas nubes que te tapan
# Y te traigo el color que te haga falta
# Pa' que luzcas de una forma bacana
# Yo te abrazo, te bailo y te cuido
# Pa' que el mundo sea más suavecito
# Si tú quieres me quedo contigo
# Pa' que el mundo sea más suavecito
# Que no estás sola, o-ooh
# Por eso digo aloha, a-a-aah
# I don't feel alone now, o-o-ooh
# Aloha, a-a-aah
# ...

# %%
import requests
import json
from bs4 import BeautifulSoup
import re
import os

songs = []
lyrics = 'Merlí Miss Caffeina'
song_title = 'Aloha'
artist_name = 'Carlos Sadness'
base_url = 'https://api.genius.com'
headers = {'Authorization': 'Bearer ' + 'iT3UxsD45-uuPA7xk2HNdcBStbhLoahWhVCKGqiR1IJ3OuO0ePtPlDTe7-70x_Xr'}
search_url = base_url + '/search'
data = {'q': lyrics}
print (data)


response = requests.get(search_url, data=data, headers=headers)


parsed = json.loads(response.text)
#print (parsed)
song_info = []
for hit in parsed['response']['hits']:
    if artist_name.lower() in hit['result']['primary_artist']['name'].lower():
        song_info.append(hit)



for song in song_info:
            if (len(songs) < 2):
                url = song['result']['url']
                songs.append(url)
                print(song['result'])
                
#print(songs)

def scrape_song_lyrics(url):
    page = requests.get(url)
    html = BeautifulSoup(page.text, 'html.parser')
    lyrics = html.find('div', class_='lyrics').get_text()
    #remove identifiers like chorus, verse, etc
    lyrics = re.sub(r'[\(\[].*?[\)\]]', '', lyrics)
    #remove empty lines
    lyrics = os.linesep.join([s for s in lyrics.splitlines() if s])         
    return lyrics

print(scrape_song_lyrics('https://genius.com/Carlos-sadness-aloha-lyrics'))
# Out:
# {'q': 'Merlí Miss Caffeina'}
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#
# C:\ProgramData\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# ...

# %%
import requests
import json
from bs4 import BeautifulSoup
import re
import os

songs = []
lyrics = 'Desde Barcelona hasta santa marta'
song_title = ' '
artist_name = ' '
base_url = 'https://api.genius.com'
headers = {'Authorization': 'Bearer ' + 'iT3UxsD45-uuPA7xk2HNdcBStbhLoahWhVCKGqiR1IJ3OuO0ePtPlDTe7-70x_Xr'}
search_url = base_url + '/search'
data = {'q': lyrics}
print (data)


response = requests.get(search_url, data=data, headers=headers)


parsed = json.loads(response.text)

print (json.dumps(parsed, indent = 4))

for hit in parsed['response']['hits']:
        song_info.append(hit)
    

for song in song_info:
            if (len(songs) < 2):
                url = song['result']['url']
                songs.append(url)
        
print('Found {} songs by {}'.format(len(songs), artist_name))
    
print(songs)

def scrape_song_lyrics(url):
    page = requests.get(url)
    html = BeautifulSoup(page.text, 'html.parser')
    lyrics = html.find('div', class_='lyrics').get_text()
    #remove identifiers like chorus, verse, etc
    lyrics = re.sub(r'[\(\[].*?[\)\]]', '', lyrics)
    #remove empty lines
    lyrics = os.linesep.join([s for s in lyrics.splitlines() if s])         
    return lyrics

print(scrape_song_lyrics(songs[0]))
# Out:
# {'q': 'Desde Barcelona hasta santa marta'}
# {
#     "meta": {
#         "status": 200
#     },
#     "response": {
#         "hits": [
#             {
#                 "highlights": [],
#                 "index": "song",
#                 "type": "song",
#                 "result": {
#                     "annotation_count": 1,
#                     "api_path": "/songs/5043553",
#                     "full_title": "Aloha by\u00a0Carlos\u00a0Sadness (Ft.\u00a0Bomba\u00a0Est\u00e9reo)",
#                     "header_image_thumbnail_url": "https://images.genius.com/8ded06a5ed4974d40c17646c0c9d6cbb.300x300x1.jpg",
#                     "header_image_url": "https://images.genius.com/8ded06a5ed4974d40c17646c0c9d6cbb.1000x1000x1.jpg",
#                     "id": 5043553,
#                     "lyrics_owner_id": 5198941,
#                     "lyrics_state": "complete",
#                     "path": "/Carlos-sadness-aloha-lyrics",
#                     "pyongs_count": null,
# ...
